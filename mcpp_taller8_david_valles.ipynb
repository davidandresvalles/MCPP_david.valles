# %% [markdown]
# # Taller 8
# Métodos Computacionales para Políticas Públicas - URosario
#
# **Entrega: viernes 21-abr-2017 11:59 PM**

# %% [markdown]
# <div class="alert alert-success">
# **[David Valles]** <br><br>
# [david.valles@urosario.edu.com]
# </div>

# %% [markdown]
# ## Instrucciones:
# - Guarde una copia de este *Jupyter Notebook* en su computador, idealmente en una carpeta destinada al material del curso.
# - Modifique el nombre del archivo del *notebook*, agregando al final un guión inferior y su nombre y apellido, separados estos últimos por otro guión inferior. Por ejemplo, mi *notebook* se llamaría: mcpp_taller8_santiago_matallana
# - Marque el *notebook* con su nombre y e-mail en el bloque verde arriba. Reemplace el texto "[Su nombre acá]" con su nombre y apellido. Similar para su e-mail.
# - Desarrolle la totalidad del taller sobre este *notebook*, insertando las celdas que sea necesario debajo de cada pregunta. Haga buen uso de las celdas para código y de las celdas tipo *markdown* según el caso.
# - Recuerde salvar periódicamente sus avances.
# - Cuando termine el taller:
#     1. Descárguelo en PDF. Si tiene algún problema con la conversión, descárguelo en HTML.
#     2. Suba todos los archivos a su repositorio en GitHub, en una carpeta destinada exclusivamente para este taller, antes de la fecha y hora límites.

# %% [markdown]
# ---

# %% [markdown]
# Vamos a hacer "scraping" a esta página: http://archive.ics.uci.edu/ml/datasets.html, que contiene un listado de 360 bases de datos que hacen parte del repositorio de la Universidad de California, Irvine.

# %% [markdown]
# Su tarea consiste en crear un "Pandas dataframe" que contenga 360 filas (una por base de datos) y las siguientes columnas:
# - Nombre de la base de datos
# - Link a la base de datos
# - Tipo de datos
# - Tipo de tarea a resolver (default task)
# - Tipo de las variables
# - Número de observaciones
# - Número de variables
# - Año
# - Descricpción de la base (Pista: Utilice la opción list view)

# %% [markdown]
# Diviértase.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://archive.ics.uci.edu/ml/datasets.html"

# %%
html = requests.get(url).text

# %%
html
# Out:
# '<!DOCTYPE HTML PUBLIC \\"-//W3C//DTD HTML 4.01 Transitional//EN\\">\n<html>\n<head>\n<title>UCI Machine Learning Repository: Data Sets</title>\n\n<!-- Stylesheet link -->\n<link rel="stylesheet" type="text/css" href="assets/ml.css" />\n\n<script language="JavaScript" type="text/javascript">\n<!--\nfunction checkform ( form )\n{\n  // see http://www.thesitewizard.com/archive/validation.shtml\n  // for an explanation of this script and how to use it on your\n  // own website\n\n  // ** START **\n  if (form.q.value == "")\n  {\n    alert( "Please enter search terms." );\n    form.q.focus();\n    return false ;\n  }\n\n  if (getCheckedValue(form.sitesearch) == "ics.uci.edu" && form.q.value.indexOf("site:archive.ics.uci.edu/ml") == -1)\n  {\n    form.q.value = form.q.value + " site:archive.ics.uci.edu/ml";\n  }\n\n  // ** END **\n  return true ;\n}\n\n// return the value of the radio button that is checked\n// return an empty string if none are checked, or\n// there are no radio buttons\
# ...

# %%
soup = BeautifulSoup(html, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <body>
#   <p>
#    "-//W3C//DTD HTML 4.01 Transitional//EN\"&gt;
#   </p>
#   <title>
#    UCI Machine Learning Repository: Data Sets
#   </title>
#   <!-- Stylesheet link -->
#   <link href="assets/ml.css" rel="stylesheet" type="text/css"/>
#   <script language="JavaScript" type="text/javascript">
#    <!--
# function checkform ( form )
# {
#   // see http://www.thesitewizard.com/archive/validation.shtml
#   // for an explanation of this script and how to use it on your
#   // own website
#
#   // ** START **
#   if (form.q.value == "")
#   {
#     alert( "Please enter search terms." );
#     form.q.focus();
#     return false ;
#   }
#
#   if (getCheckedValue(form.sitesearch) == "ics.uci.edu" && form.q.value.indexOf("site:archive.ics.uci.edu/ml") == -1)
#   {
#     form.q.value = form.q.value + " site:archive.ics.uci.edu/ml";
#   }
#
#   // ** END **
#   return true ;
# }
#
# // return the value of the radio button that is checked
# ...

# %% [markdown]
# ### Link a la base de datos

# %%
links = soup.find_all('a')

# %%
links
# Out:
# [<a alt="Home" href="index.html"><img border="0" src="assets/logo.gif"/></a>,
#  <a href="http://cml.ics.uci.edu"><font color="FFDD33">Center for Machine Learning and Intelligent Systems</font></a>,
#  <a href="about.html">About</a>,
#  <a href="citation_policy.html">Citation Policy</a>,
#  <a href="donation_policy.html">Donate a Data Set</a>,
#  <a href="contact.html">Contact</a>,
#  <a href="http://www.google.com/search"><img align="middle" alt="Google" border="0" height="27" src="http://www.google.com/logos/Logo_25blk.gif"/></a>,
#  <a href="datasets.html"><font color="#FFDD33" size="3"><b>View ALL Data Sets</b></font></a>,
#  <a href="datasets.html?format=&amp;task=cla&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Classification</a>,
#  <a href="datasets.html?format=&amp;task=reg&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Regression</a>,
# ...

# %%
len(links)
# Out:
# 774

# %%
import re

# %%
re.findall('"(datasets/.+?)"', str(links))
# Out:
# ['datasets/Abalone',
#  'datasets/Abalone',
#  'datasets/Adult',
#  'datasets/Adult',
#  'datasets/Annealing',
#  'datasets/Annealing',
#  'datasets/Anonymous+Microsoft+Web+Data',
#  'datasets/Anonymous+Microsoft+Web+Data',
#  'datasets/Arrhythmia',
#  'datasets/Arrhythmia',
#  'datasets/Artificial+Characters',
#  'datasets/Artificial+Characters',
#  'datasets/Audiology+%28Original%29',
#  'datasets/Audiology+%28Original%29',
#  'datasets/Audiology+%28Standardized%29',
#  'datasets/Audiology+%28Standardized%29',
#  'datasets/Auto+MPG',
#  'datasets/Auto+MPG',
#  'datasets/Automobile',
#  'datasets/Automobile',
#  'datasets/Badges',
#  'datasets/Badges',
#  'datasets/Balance+Scale',
#  'datasets/Balance+Scale',
#  'datasets/Balloons',
#  'datasets/Balloons',
#  'datasets/Breast+Cancer',
#  'datasets/Breast+Cancer',
#  'datasets/Breast+Cancer+Wisconsin+%28Original%29',
#  'datasets/Breast+Cancer+Wisconsin+%28Original%29',
#  'datasets/Breast+Cancer+Wisconsin+%28Prognostic%29',
# ...

# %%
lista_links= (re.findall('"(datasets/.+?)"', str(links)))

# %%
lista_links1 = []
for i in lista_links:
    if i not in lista_links1:
        lista_links1.append(i)

# %%
lista_links1
# Out:
# ['datasets/Abalone',
#  'datasets/Adult',
#  'datasets/Annealing',
#  'datasets/Anonymous+Microsoft+Web+Data',
#  'datasets/Arrhythmia',
#  'datasets/Artificial+Characters',
#  'datasets/Audiology+%28Original%29',
#  'datasets/Audiology+%28Standardized%29',
#  'datasets/Auto+MPG',
#  'datasets/Automobile',
#  'datasets/Badges',
#  'datasets/Balance+Scale',
#  'datasets/Balloons',
#  'datasets/Breast+Cancer',
#  'datasets/Breast+Cancer+Wisconsin+%28Original%29',
#  'datasets/Breast+Cancer+Wisconsin+%28Prognostic%29',
#  'datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29',
#  'datasets/Pittsburgh+Bridges',
#  'datasets/Car+Evaluation',
#  'datasets/Census+Income',
#  'datasets/Chess+%28King-Rook+vs.+King-Knight%29',
#  'datasets/Chess+%28King-Rook+vs.+King-Pawn%29',
#  'datasets/Chess+%28King-Rook+vs.+King%29',
#  'datasets/Chess+%28Domain+Theories%29',
#  'datasets/Bach+Chorales',
#  'datasets/Connect-4',
#  'datasets/Credit+Approval',
#  'datasets/Japanese+Credit+Screening',
# ...

# %%
links1=[]
for x in lista_links1: 
    links1.append ("http://archive.ics.uci.edu/ml/" + str(x))

# %%
links1
# Out:
# ['http://archive.ics.uci.edu/ml/datasets/Abalone',
#  'http://archive.ics.uci.edu/ml/datasets/Adult',
#  'http://archive.ics.uci.edu/ml/datasets/Annealing',
#  'http://archive.ics.uci.edu/ml/datasets/Anonymous+Microsoft+Web+Data',
#  'http://archive.ics.uci.edu/ml/datasets/Arrhythmia',
#  'http://archive.ics.uci.edu/ml/datasets/Artificial+Characters',
#  'http://archive.ics.uci.edu/ml/datasets/Audiology+%28Original%29',
#  'http://archive.ics.uci.edu/ml/datasets/Audiology+%28Standardized%29',
#  'http://archive.ics.uci.edu/ml/datasets/Auto+MPG',
#  'http://archive.ics.uci.edu/ml/datasets/Automobile',
#  'http://archive.ics.uci.edu/ml/datasets/Badges',
#  'http://archive.ics.uci.edu/ml/datasets/Balance+Scale',
#  'http://archive.ics.uci.edu/ml/datasets/Balloons',
#  'http://archive.ics.uci.edu/ml/datasets/Breast+Cancer',
#  'http://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Original%29',
# ...

# %% [markdown]
# ### Nombre de la base de datos

# %%
lista_links1
# Out:
# ['datasets/Abalone',
#  'datasets/Adult',
#  'datasets/Annealing',
#  'datasets/Anonymous+Microsoft+Web+Data',
#  'datasets/Arrhythmia',
#  'datasets/Artificial+Characters',
#  'datasets/Audiology+%28Original%29',
#  'datasets/Audiology+%28Standardized%29',
#  'datasets/Auto+MPG',
#  'datasets/Automobile',
#  'datasets/Badges',
#  'datasets/Balance+Scale',
#  'datasets/Balloons',
#  'datasets/Breast+Cancer',
#  'datasets/Breast+Cancer+Wisconsin+%28Original%29',
#  'datasets/Breast+Cancer+Wisconsin+%28Prognostic%29',
#  'datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29',
#  'datasets/Pittsburgh+Bridges',
#  'datasets/Car+Evaluation',
#  'datasets/Census+Income',
#  'datasets/Chess+%28King-Rook+vs.+King-Knight%29',
#  'datasets/Chess+%28King-Rook+vs.+King-Pawn%29',
#  'datasets/Chess+%28King-Rook+vs.+King%29',
#  'datasets/Chess+%28Domain+Theories%29',
#  'datasets/Bach+Chorales',
#  'datasets/Connect-4',
#  'datasets/Credit+Approval',
#  'datasets/Japanese+Credit+Screening',
# ...

# %%
nombres_str=map(str, lista_links1)

# %% [markdown]
# ### Tipo de datos

# %%
datos = soup.find_all('p')

# %%
datos
# Out:
# [<p>"-//W3C//DTD HTML 4.01 Transitional//EN\"&gt;
#
#  </p>,
#  <p align="center" class="big">Browse Through:</p>,
#  <p class="whitetext"><b>Default Task</b> </p>,
#  <p class="normal"><a href="datasets.html?format=&amp;task=cla&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Classification</a> <font color="red">(263)</font><br/><a href="datasets.html?format=&amp;task=reg&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Regression</a> <font color="red">(64)</font><br/><a href="datasets.html?format=&amp;task=clu&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Clustering</a> <font color="red">(55)</font><br/><a href="datasets.html?format=&amp;task=other&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Other</a> <font color="red">(52)</font> </p>,
#  <p class="whitetext"><b>Attribute Type</b> </p>,
# ...

# %%
datos[25]
# Out:
# <p class="normal"><b><a href="datasets/Abalone">Abalone</a></b></p>

# %%
datos[2558]
# Out:
# <p class="normal">2016 </p>

# %%
datos1=datos[25:2559]

# %%
datos1
# Out:
# [<p class="normal"><b><a href="datasets/Abalone">Abalone</a></b></p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal">4177 </p>,
#  <p class="normal">8 </p>,
#  <p class="normal">1995 </p>,
#  <p class="normal"><b><a href="datasets/Adult">Adult</a></b></p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Categorical, Integer </p>,
#  <p class="normal">48842 </p>,
#  <p class="normal">14 </p>,
#  <p class="normal">1996 </p>,
#  <p class="normal"><b><a href="datasets/Annealing">Annealing</a></b></p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal">798 </p>,
#  <p class="normal">38 </p>,
#  <p class="normal"> </p>,
# ...

# %%
len(datos1)
# Out:
# 2534

# %%
tipo_datos=datos1[1:2534:7]

# %%
tipo_datos
# Out:
# [<p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal"> </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Univariate, Text </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate, Data-Generator </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Multivariate </p>,
#  <p class="normal">Domain-Theory </p>,
# ...

# %%
datos_str=map(str, tipo_datos)

# %% [markdown]
# ### Tipo de tarea a resolver (default task)

# %%
tipo_tarea=datos1[2:2534:7]

# %%
re.findall('"(Multivariate.+?)"', str(links))
# Out:
# []

# %%
tipo_tarea
# Out:
# [<p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Recommender-Systems </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Regression </p>,
#  <p class="normal">Regression </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification, Regression </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
#  <p class="normal">Classification </p>,
# ...

# %% [markdown]
# ### Tipo de las variables

# %%
tipo_var=datos1[3:2534:7]

# %%
tipo_var
# Out:
# [<p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal">Categorical, Integer </p>,
#  <p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical, Real </p>,
#  <p class="normal">Categorical, Integer, Real </p>,
#  <p class="normal"> </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Integer </p>,
#  <p class="normal">Real </p>,
#  <p class="normal">Real </p>,
#  <p class="normal">Categorical, Integer </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical, Integer </p>,
#  <p class="normal">Categorical, Integer </p>,
#  <p class="normal">Categorical </p>,
#  <p class="normal">Categorical, Integer </p>,
# ...

# %% [markdown]
# ### Número de observaciones

# %%
numero_obs=datos1[4:2534:7]

# %%
numero_obs
# Out:
# [<p class="normal">4177 </p>,
#  <p class="normal">48842 </p>,
#  <p class="normal">798 </p>,
#  <p class="normal">37711 </p>,
#  <p class="normal">452 </p>,
#  <p class="normal">6000 </p>,
#  <p class="normal">226 </p>,
#  <p class="normal">226 </p>,
#  <p class="normal">398 </p>,
#  <p class="normal">205 </p>,
#  <p class="normal">294 </p>,
#  <p class="normal">625 </p>,
#  <p class="normal">16 </p>,
#  <p class="normal">286 </p>,
#  <p class="normal">699 </p>,
#  <p class="normal">198 </p>,
#  <p class="normal">569 </p>,
#  <p class="normal">108 </p>,
#  <p class="normal">1728 </p>,
#  <p class="normal">48842 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">3196 </p>,
#  <p class="normal">28056 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">100 </p>,
#  <p class="normal">67557 </p>,
#  <p class="normal">690 </p>,
#  <p class="normal">125 </p>,
#  <p class="normal">209 </p>,
#  <p class="normal">1473 </p>,
#  <p class="normal">581012 </p>,
# ...

# %% [markdown]
# ### Número de variables

# %%
numero_var=datos1[5:2534:7]

# %%
numero_var
# Out:
# [<p class="normal">8 </p>,
#  <p class="normal">14 </p>,
#  <p class="normal">38 </p>,
#  <p class="normal">294 </p>,
#  <p class="normal">279 </p>,
#  <p class="normal">7 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">69 </p>,
#  <p class="normal">8 </p>,
#  <p class="normal">26 </p>,
#  <p class="normal">1 </p>,
#  <p class="normal">4 </p>,
#  <p class="normal">4 </p>,
#  <p class="normal">9 </p>,
#  <p class="normal">10 </p>,
#  <p class="normal">34 </p>,
#  <p class="normal">32 </p>,
#  <p class="normal">13 </p>,
#  <p class="normal">6 </p>,
#  <p class="normal">14 </p>,
#  <p class="normal">22 </p>,
#  <p class="normal">36 </p>,
#  <p class="normal">6 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">6 </p>,
#  <p class="normal">42 </p>,
#  <p class="normal">15 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">9 </p>,
#  <p class="normal">9 </p>,
#  <p class="normal">54 </p>,
#  <p class="normal">39 </p>,
#  <p class="normal">33 </p>,
# ...

# %%
numero_var_str=map(str, numero_var)

# %% [markdown]
# ### Año

# %%
año=datos1[6:2534:7]

# %%
año
# Out:
# [<p class="normal">1995 </p>,
#  <p class="normal">1996 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">1998 </p>,
#  <p class="normal">1998 </p>,
#  <p class="normal">1992 </p>,
#  <p class="normal">1987 </p>,
#  <p class="normal">1992 </p>,
#  <p class="normal">1993 </p>,
#  <p class="normal">1987 </p>,
#  <p class="normal">1994 </p>,
#  <p class="normal">1994 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">1988 </p>,
#  <p class="normal">1992 </p>,
#  <p class="normal">1995 </p>,
#  <p class="normal">1995 </p>,
#  <p class="normal">1990 </p>,
#  <p class="normal">1997 </p>,
#  <p class="normal">1996 </p>,
#  <p class="normal">1988 </p>,
#  <p class="normal">1989 </p>,
#  <p class="normal">1994 </p>,
#  <p class="normal"> </p>,
#  <p class="normal"> </p>,
#  <p class="normal">1995 </p>,
#  <p class="normal"> </p>,
#  <p class="normal">1992 </p>,
#  <p class="normal">1987 </p>,
#  <p class="normal">1997 </p>,
#  <p class="normal">1998 </p>,
# ...

# %% [markdown]
# ### Descricpción de la base (Pista: Utilice la opción list view)

# %%
from bs4 import Comment

# %%
comments = soup.findAll(text=lambda text:isinstance(text, Comment))

# %%
comments
# Out:
# [' Stylesheet link ',
#  ' SITE HEADER (INCLUDES LOGO AND SEARCH BOX) ',
#  ' SITE HEADER (INCLUDES LOGO AND SEARCH BOX) ',
#  ' Search Google ',
#  ' Search Google ',
#  ' <td><p class="normal, whitetext"><b>Abstract</b></p></td> ',
#  ' <td><p class="normal, whitetext"><b>Area</b></p></td> ',
#  ' <td><p class="normal">Predict the age of abalone from physical measurements&nbsp;</p></td> ',
#  ' <td><p class="normal">Life&nbsp;</p></td> ',
#  ' <td><p class="normal">Predict whether income exceeds $50K/yr based on census data.  Also known as "Census Income" dataset.&nbsp;</p></td> ',
#  ' <td><p class="normal">Social&nbsp;</p></td> ',
#  ' <td><p class="normal">Steel annealing data&nbsp;</p></td> ',
#  ' <td><p class="normal">Physical&nbsp;</p></td> ',
#  ' <td><p class="normal">Log of anonymous users of www.microsoft.com; predict areas of the web site a user visited based on data on other areas the user visited.&nbsp;</p></td> ',
# ...

# %%
descripcion_base=comments[7:731:2]

# %%
descripcion_base
# Out:
# [' <td><p class="normal">Predict the age of abalone from physical measurements&nbsp;</p></td> ',
#  ' <td><p class="normal">Predict whether income exceeds $50K/yr based on census data.  Also known as "Census Income" dataset.&nbsp;</p></td> ',
#  ' <td><p class="normal">Steel annealing data&nbsp;</p></td> ',
#  ' <td><p class="normal">Log of anonymous users of www.microsoft.com; predict areas of the web site a user visited based on data on other areas the user visited.&nbsp;</p></td> ',
#  ' <td><p class="normal">Distinguish between the presence and absence of cardiac arrhythmia and classify it in one of the 16 groups.&nbsp;</p></td> ',
#  ' <td><p class="normal">Dataset artificially generated by using first order theory which describes structure of ten capital letters of English alphabet&nbsp;</p></td> ',
#  ' <td><p class="normal">Nominal audiology dataset from Baylor&nbsp;</p></td> ',
# ...

# %%
len(descripcion_base)
# Out:
# 362

# %% [markdown]
# ### Panda

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd_links=pd.DataFrame(links1)

# %%
pd_links.columns=['links']

# %%
pd_links
# Out:
#                                                  links
# 0       http://archive.ics.uci.edu/ml/datasets/Abalone
# 1         http://archive.ics.uci.edu/ml/datasets/Adult
# 2     http://archive.ics.uci.edu/ml/datasets/Annealing
# 3    http://archive.ics.uci.edu/ml/datasets/Anonymo...
# 4    http://archive.ics.uci.edu/ml/datasets/Arrhythmia
# 5    http://archive.ics.uci.edu/ml/datasets/Artific...
# 6    http://archive.ics.uci.edu/ml/datasets/Audiolo...
# 7    http://archive.ics.uci.edu/ml/datasets/Audiolo...
# 8      http://archive.ics.uci.edu/ml/datasets/Auto+MPG
# 9    http://archive.ics.uci.edu/ml/datasets/Automobile
# 10       http://archive.ics.uci.edu/ml/datasets/Badges
# 11   http://archive.ics.uci.edu/ml/datasets/Balance...
# 12     http://archive.ics.uci.edu/ml/datasets/Balloons
# 13   http://archive.ics.uci.edu/ml/datasets/Breast+...
# 14   http://archive.ics.uci.edu/ml/datasets/Breast+...
# 15   http://archive.ics.uci.edu/ml/datasets/Breast+...
# ...

# %%
pd_nombre=pd.DataFrame(lista_links1)

# %%
pd_nombre.columns=['nombre de base de datos']

# %%
pd_nombre
# Out:
#                                nombre de base de datos
# 0                                     datasets/Abalone
# 1                                       datasets/Adult
# 2                                   datasets/Annealing
# 3                datasets/Anonymous+Microsoft+Web+Data
# 4                                  datasets/Arrhythmia
# 5                       datasets/Artificial+Characters
# 6                    datasets/Audiology+%28Original%29
# 7                datasets/Audiology+%28Standardized%29
# 8                                    datasets/Auto+MPG
# 9                                  datasets/Automobile
# 10                                     datasets/Badges
# 11                              datasets/Balance+Scale
# 12                                   datasets/Balloons
# 13                              datasets/Breast+Cancer
# 14     datasets/Breast+Cancer+Wisconsin+%28Original%29
# 15   datasets/Breast+Cancer+Wisconsin+%28Prognostic%29
# ...

# %%
pd_tipo=pd.DataFrame(tipo_datos)

# %%
pd_tipo.columns=['tipo de datos']

# %%
pd_tipo
# Out:
#                                          tipo de datos
# 0                  <p class="normal">Multivariate </p>
# 1                  <p class="normal">Multivariate </p>
# 2                  <p class="normal">Multivariate </p>
# 3                              <p class="normal"> </p>
# 4                  <p class="normal">Multivariate </p>
# 5                  <p class="normal">Multivariate </p>
# 6                  <p class="normal">Multivariate </p>
# 7                  <p class="normal">Multivariate </p>
# 8                  <p class="normal">Multivariate </p>
# 9                  <p class="normal">Multivariate </p>
# 10             <p class="normal">Univariate, Text </p>
# 11                 <p class="normal">Multivariate </p>
# 12                 <p class="normal">Multivariate </p>
# 13                 <p class="normal">Multivariate </p>
# 14                 <p class="normal">Multivariate </p>
# 15                 <p class="normal">Multivariate </p>
# ...

# %%
pd_tipo_tarea=pd.DataFrame(tipo_tarea)

# %%
pd_tipo_tarea.columns=['tipo de tarea']

# %%
pd_tipo_tarea
# Out:
#                                          tipo de tarea
# 0                <p class="normal">Classification </p>
# 1                <p class="normal">Classification </p>
# 2                <p class="normal">Classification </p>
# 3           <p class="normal">Recommender-Systems </p>
# 4                <p class="normal">Classification </p>
# 5                <p class="normal">Classification </p>
# 6                <p class="normal">Classification </p>
# 7                <p class="normal">Classification </p>
# 8                    <p class="normal">Regression </p>
# 9                    <p class="normal">Regression </p>
# 10               <p class="normal">Classification </p>
# 11               <p class="normal">Classification </p>
# 12               <p class="normal">Classification </p>
# 13               <p class="normal">Classification </p>
# 14               <p class="normal">Classification </p>
# 15   <p class="normal">Classification, Regression </p>
# ...

# %%
pd_tipo_var=pd.DataFrame(tipo_var)

# %%
pd_tipo_var.columns=['tipo de variables']

# %%
pd_tipo_var
# Out:
#                                      tipo de variables
# 0    <p class="normal">Categorical, Integer, Real </p>
# 1          <p class="normal">Categorical, Integer </p>
# 2    <p class="normal">Categorical, Integer, Real </p>
# 3                   <p class="normal">Categorical </p>
# 4    <p class="normal">Categorical, Integer, Real </p>
# 5    <p class="normal">Categorical, Integer, Real </p>
# 6                   <p class="normal">Categorical </p>
# 7                   <p class="normal">Categorical </p>
# 8             <p class="normal">Categorical, Real </p>
# 9    <p class="normal">Categorical, Integer, Real </p>
# 10                             <p class="normal"> </p>
# 11                  <p class="normal">Categorical </p>
# 12                  <p class="normal">Categorical </p>
# 13                  <p class="normal">Categorical </p>
# 14                      <p class="normal">Integer </p>
# 15                         <p class="normal">Real </p>
# ...

# %%
pd_num_obs=pd.DataFrame(numero_obs)

# %%
pd_num_obs.columns=['numero de observaciones']

# %%
pd_num_obs
# Out:
#              numero de observaciones
# 0        <p class="normal">4177 </p>
# 1       <p class="normal">48842 </p>
# 2         <p class="normal">798 </p>
# 3       <p class="normal">37711 </p>
# 4         <p class="normal">452 </p>
# 5        <p class="normal">6000 </p>
# 6         <p class="normal">226 </p>
# 7         <p class="normal">226 </p>
# 8         <p class="normal">398 </p>
# 9         <p class="normal">205 </p>
# 10        <p class="normal">294 </p>
# 11        <p class="normal">625 </p>
# 12         <p class="normal">16 </p>
# 13        <p class="normal">286 </p>
# 14        <p class="normal">699 </p>
# 15        <p class="normal">198 </p>
# 16        <p class="normal">569 </p>
# 17        <p class="normal">108 </p>
# 18       <p class="normal">1728 </p>
# 19      <p class="normal">48842 </p>
# 20           <p class="normal"> </p>
# 21       <p class="normal">3196 </p>
# 22      <p class="normal">28056 </p>
# 23           <p class="normal"> </p>
# ...

# %%
pd_num_var=pd.DataFrame(numero_var)

# %%
pd_num_var.columns=['numero de variables']

# %%
pd_num_var
# Out:
#                numero de variables
# 0         <p class="normal">8 </p>
# 1        <p class="normal">14 </p>
# 2        <p class="normal">38 </p>
# 3       <p class="normal">294 </p>
# 4       <p class="normal">279 </p>
# 5         <p class="normal">7 </p>
# 6          <p class="normal"> </p>
# 7        <p class="normal">69 </p>
# 8         <p class="normal">8 </p>
# 9        <p class="normal">26 </p>
# 10        <p class="normal">1 </p>
# 11        <p class="normal">4 </p>
# 12        <p class="normal">4 </p>
# 13        <p class="normal">9 </p>
# 14       <p class="normal">10 </p>
# 15       <p class="normal">34 </p>
# 16       <p class="normal">32 </p>
# 17       <p class="normal">13 </p>
# 18        <p class="normal">6 </p>
# 19       <p class="normal">14 </p>
# 20       <p class="normal">22 </p>
# 21       <p class="normal">36 </p>
# 22        <p class="normal">6 </p>
# 23         <p class="normal"> </p>
# 24        <p class="normal">6 </p>
# 25       <p class="normal">42 </p>
# ...

# %%
pd_año = pd.DataFrame(año)

# %%
pd_año.columns=['año']

# %%
pd_año
# Out:
#                              año
# 0    <p class="normal">1995 </p>
# 1    <p class="normal">1996 </p>
# 2        <p class="normal"> </p>
# 3    <p class="normal">1998 </p>
# 4    <p class="normal">1998 </p>
# 5    <p class="normal">1992 </p>
# 6    <p class="normal">1987 </p>
# 7    <p class="normal">1992 </p>
# 8    <p class="normal">1993 </p>
# 9    <p class="normal">1987 </p>
# 10   <p class="normal">1994 </p>
# 11   <p class="normal">1994 </p>
# 12       <p class="normal"> </p>
# 13   <p class="normal">1988 </p>
# 14   <p class="normal">1992 </p>
# 15   <p class="normal">1995 </p>
# 16   <p class="normal">1995 </p>
# 17   <p class="normal">1990 </p>
# 18   <p class="normal">1997 </p>
# 19   <p class="normal">1996 </p>
# 20   <p class="normal">1988 </p>
# 21   <p class="normal">1989 </p>
# 22   <p class="normal">1994 </p>
# 23       <p class="normal"> </p>
# 24       <p class="normal"> </p>
# 25   <p class="normal">1995 </p>
# 26       <p class="normal"> </p>
# ...

# %%
pd_descrip=pd.DataFrame(descripcion_base)

# %%
pd_descrip.columns=['descripcion de la base de datos']

# %%
pd_descrip
# Out:
#                        descripcion de la base de datos
# 0     <td><p class="normal">Predict the age of abal...
# 1     <td><p class="normal">Predict whether income ...
# 2     <td><p class="normal">Steel annealing data&nb...
# 3     <td><p class="normal">Log of anonymous users ...
# 4     <td><p class="normal">Distinguish between the...
# 5     <td><p class="normal">Dataset artificially ge...
# 6     <td><p class="normal">Nominal audiology datas...
# 7     <td><p class="normal">Standardized version of...
# 8     <td><p class="normal">Revised from CMU StatLi...
# 9     <td><p class="normal">From 1985 Ward's Automo...
# 10    <td><p class="normal">Badges labeled with a "...
# 11    <td><p class="normal">Balance scale weight & ...
# 12    <td><p class="normal">Data previously used in...
# 13    <td><p class="normal">Breast Cancer Data (Res...
# 14    <td><p class="normal">Original Wisconsin Brea...
# 15    <td><p class="normal">Prognostic Wisconsin Br...
# ...

# %% [markdown]
# Juntando columnas

# %%
pd_bdd= pd.concat([pd_links,pd_nombre,pd_tipo, pd_tipo_tarea, pd_tipo_var,pd_num_obs, pd_num_var, pd_año,pd_descrip], axis=1)

# %%
pd_bdd
# Out:
#                                                  links  \
# 0       http://archive.ics.uci.edu/ml/datasets/Abalone
# 1         http://archive.ics.uci.edu/ml/datasets/Adult
# 2     http://archive.ics.uci.edu/ml/datasets/Annealing
# 3    http://archive.ics.uci.edu/ml/datasets/Anonymo...
# 4    http://archive.ics.uci.edu/ml/datasets/Arrhythmia
# 5    http://archive.ics.uci.edu/ml/datasets/Artific...
# 6    http://archive.ics.uci.edu/ml/datasets/Audiolo...
# 7    http://archive.ics.uci.edu/ml/datasets/Audiolo...
# 8      http://archive.ics.uci.edu/ml/datasets/Auto+MPG
# 9    http://archive.ics.uci.edu/ml/datasets/Automobile
# 10       http://archive.ics.uci.edu/ml/datasets/Badges
# 11   http://archive.ics.uci.edu/ml/datasets/Balance...
# 12     http://archive.ics.uci.edu/ml/datasets/Balloons
# 13   http://archive.ics.uci.edu/ml/datasets/Breast+...
# 14   http://archive.ics.uci.edu/ml/datasets/Breast+...
# 15   http://archive.ics.uci.edu/ml/datasets/Breast+...
# ...

# %% [markdown]
# # no pude utilizar  regular expression porque en los casos que las variables no tenian valores se me reducia el número de observaciones.
